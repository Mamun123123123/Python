# %%
print("hello")
# Out:
# hello

# %%
def hello():
    print("Hello")
hello()
# Out:
# Hello

# %%
pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.3 MB 1.8 MB/s eta 0:00:07
#    --- ------------------------------------ 1.0/12.3 MB 2.0 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.3/12.3 MB 2.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.8/12.3 MB 2.0 MB/s eta 0:00:06
#    ------ --------------------------------- 2.1/12.3 MB 2.0 MB/s eta 0:00:06
#    ------- -------------------------------- 2.4/12.3 MB 1.9 MB/s eta 0:00:06
#    --------- ------------------------------ 2.9/12.3 MB 1.9 MB/s eta 0:00:06
#    ----------- ---------------------------- 3.4/12.3 MB 1.9 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.7/12.3 MB 1.9 MB/s eta 0:00:05
#    ------------ --------------------------- 3.9/12.3 MB 1.9 MB/s eta 0:00:05
# ...

# %%
import numpy as np
arr = np.array([1,2,3,4])
print(arr)
# Out:
# [1 2 3 4]
