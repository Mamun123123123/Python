# %%
import pandas as pd
df = pd.read_csv(r"D:\python\popular_anime.csv")
df.head()
# Out:
#       id                              name                             genres  \
# 0  52991     Frieren: Beyond Journey's End          Adventure, Drama, Fantasy
# 1   5114  Fullmetal Alchemist: Brotherhood  Action, Adventure, Drama, Fantasy
# 2   9253                       Steins;Gate            Drama, Sci-Fi, Suspense
# 3  38524   Attack on Titan Season 3 Part 2            Action, Drama, Suspense
# 4  28977                  Gintama Season 4             Action, Comedy, Sci-Fi
#
#   type  episodes           status                 aired_from  \
# 0   TV      28.0  Finished Airing  2023-09-29T00:00:00+00:00
# 1   TV      64.0  Finished Airing  2009-04-05T00:00:00+00:00
# 2   TV      24.0  Finished Airing  2011-04-06T00:00:00+00:00
# 3   TV      10.0  Finished Airing  2019-04-29T00:00:00+00:00
# 4   TV      51.0  Finished Airing  2015-04-08T00:00:00+00:00
#
#                     aired_to duration_per_ep  score  scored_by  rank  \
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 28820    False
# 28821    False
# 28822    False
# 28823    False
# 28824    False
# Length: 28825, dtype: bool

# %%
df[df["episodes"]<20]
# Out:
#           id                                               name  \
# 3      38524                    Attack on Titan Season 3 Part 2
# 5      60022                               One Piece Fan Letter
# 6      39486                            Gintama: The Very Final
# 9      15417                                 Gintama: Enchousen
# 11     41467                    Bleach: Thousand-Year Blood War
# ...      ...                                                ...
# 28820  16796                               Mujeokcheorin Rambot
# 28821  48866         Hua Jianghu: Huan Shi Men Sheng 2nd Season
# 28822  16790                                   Super Samchongsa
# 28823  16788  Sengoku Bushou Retsuden Bakufuu Douji Hissatsuman
# 28824  16784                                            Marin X
#
#                                  genres        type  episodes  \
# 3               Action, Drama, Suspense          TV      10.0
# 5            Action, Adventure, Fantasy  TV Special       1.0
# ...

# %%
d = df.groupby("type")
for i,v in d:
    print(i)
    print(v)
# Out:
# CM
#           id                                               name  \
# 735    42166                              Violet Evergarden CMs
# 1584   36064                                   Fate/Grand Order
# 1998   48953  Natsume's Book of Friends: A Day Out in Hitoyo...
# 2131   53933                                       Proof of Two
# 2973   22839                                         Cross Road
# ...      ...                                                ...
# 27286  29749                  Convenience Store Senki Purin-tai
# 27328  42542                        Pittarazu Gekijou Manner CM
# 27371  29359                                   Bazar dé Gozarre
# 27381  42698             Nissan Note x The World of Golden Eggs
# 27613  43321                          Cancerfund x Din Dong CMs
#
#                 genres type  episodes            status  \
# 735              Drama   CM       2.0   Finished Airing
# 1584   Action, Fantasy   CM       NaN  Currently Airing
# ...

# %%
f =df[df["type"]=="TV"].sum()
for i,v in f:
    print(v)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 f =df[df["type"]=="TV"].sum()
# ----> 2 for i,v in f:
#       3     print(v)
#
# TypeError: cannot unpack non-iterable numpy.int64 object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 28825 entries, 0 to 28824
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               28825 non-null  int64
#  1   name             28825 non-null  str
#  2   genres           22756 non-null  str
#  3   type             28738 non-null  str
#  4   episodes         28046 non-null  float64
#  5   status           28825 non-null  str
#  6   aired_from       27870 non-null  str
#  7   aired_to         10930 non-null  str
#  8   duration_per_ep  28825 non-null  str
#  9   score            18599 non-null  float64
#  10  scored_by        18599 non-null  float64
#  11  rank             21962 non-null  float64
#  12  rating           28101 non-null  str
#  13  studios          16936 non-null  str
#  14  producers        13452 non-null  str
#  15  image            28825 non-null  str
#  16  trailer          5474 non-null   str
# ...
