# %%
import numpy as np
import pandas as pd
arr = np.array([1,2])
print(arr)
# Out:
# [1 2]

# %%
import numpy as np
import pandas as pd
labels = ['a','b','c']
my_list = [10,20,30]
arr = np.array([10,20,30])
d = {1:10,2:20,3:30}
# pd.Series(my_list,index=labels)
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
data = {
    "name": ["Rahim", "Karim", "Arafat"],
    "age": [25, 30, 22],
    "city": ["Dhaka", "Chittagong", "Khulna"],
    "salary": [50000, 60000, 45000]
}

pd.DataFrame(data)
# Out:
#      name  age        city  salary
# 0   Rahim   25       Dhaka   50000
# 1   Karim   30  Chittagong   60000
# 2  Arafat   22      Khulna   45000

# %%
data_list = [
    ["Rahim", 25, "Dhaka", 50000],
    ["Karim", 30, "Chittagong", 60000],
    ["Arafat", 22, "Khulna", 45000]
]
df = pd.DataFrame(data_list)
df
# Out:
#         0   1           2      3
# 0   Rahim  25       Dhaka  50000
# 1   Karim  30  Chittagong  60000
# 2  Arafat  22      Khulna  45000

# %%
data_list = [
    {"name": "Rahim", "age": 25, "city": "Dhaka", "salary": 50000},
    {"name": "Karim", "age": 30, "city": "Chittagong", "salary": 60000},
    {"name": "Arafat", "age": 22, "city": "Khulna", "salary": 45000}
]
df1 = pd.DataFrame(data_list)
df1
# Out:
#      name  age        city  salary
# 0   Rahim   25       Dhaka   50000
# 1   Karim   30  Chittagong   60000
# 2  Arafat   22      Khulna   45000

# %%
df1["name"]
# Out:
# 0     Rahim
# 1     Karim
# 2    Arafat
# Name: name, dtype: str

# %%
df1[["name","age"]]
# Out:
#      name  age
# 0   Rahim   25
# 1   Karim   30
# 2  Arafat   22

# %%
df1["About"] = ["cse","EEE","civil"]
df1
# Out:
#      name  age        city  salary  About
# 0   Rahim   25       Dhaka   50000    cse
# 1   Karim   30  Chittagong   60000    EEE
# 2  Arafat   22      Khulna   45000  civil

# %%
df1.drop("About",axis=1,inplace=True)
df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df1.drop("About",axis=1,inplace=True)
#       2 df1
#
# File c:\Users\GLOBAL TECHNOLOGY\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6284                 weight  250.0   150.0
#    6285         falcon  speed   320.0   250.0
#    6286                 weight  1.0     0.8
#    6287         """
# -> 6288         return super().drop(
#    6289             labels=labels,
#    6290             axis=axis,
#    6291             index=index,
#
# File c:\Users\GLOBAL TECHNOLOGY\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4640         obj = self
#    4641
# ...

# %%
df1
# Out:
#      name  age        city  salary
# 0   Rahim   25       Dhaka   50000
# 1   Karim   30  Chittagong   60000
# 2  Arafat   22      Khulna   45000

# %%
 df1
# Out:
#      name  age        city  salary
# 0   Rahim   25       Dhaka   50000
# 1   Karim   30  Chittagong   60000
# 2  Arafat   22      Khulna   45000

# %%
df1.loc[[0,1]]
# Out:
#     name  age        city  salary
# 0  Rahim   25       Dhaka   50000
# 1  Karim   30  Chittagong   60000

# %%
df1.loc[[0,1]][["city","salary"]]
# Out:
#          city  salary
# 0       Dhaka   50000
# 1  Chittagong   60000

# %%
df1
# Out:
#      name  age        city  salary
# 0   Rahim   25       Dhaka   50000
# 1   Karim   30  Chittagong   60000
# 2  Arafat   22      Khulna   45000

# %%
df1.loc[[1,2]][["age","salary"]]
# Out:
#    age  salary
# 1   30   60000
# 2   22   45000

# %%
df1[df1["age"]>26]
# Out:
#     name  age        city  salary
# 1  Karim   30  Chittagong   60000
