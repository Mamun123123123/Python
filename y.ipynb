# %%
print("Hello")
# Out:
# Hello

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([1,2,3,4])
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x1a856ec9e80>,
# ...
#  [Text(1.0461621649530053, 0.3399187029582827, ''),
#   Text(0.33991865722907993, 1.0461621798113232, ''),
#   Text(-1.046162235191088, 0.33991848678762215, ''),
#   Text(0.33991884014588697, -1.0461621203780394, '')])

# %%
y = x**2
plt.subplot(2,2,1)
plt.subplot(2,2,2)

plt.subplot(2,2,3)
plt.plot(x,y)
